# %%
import pandas as pd 
import numpy as np
import prepare_github as prepare

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                                     repo    language
# 0                   imartinez/privateGPT      Python  \
# 1                Gioman101/FlipperAmiibo      Python
# 2                          yuzu-emu/yuzu         C++
# 3   AUTOMATIC1111/stable-diffusion-webui      Python
# 4                      go-skynet/LocalAI          Go
# 5               Yidadaa/ChatGPT-Next-Web  TypeScript
# 6                     webwhiz-ai/webwhiz  TypeScript
# 7                     UberGuidoZ/Flipper           C
# 8                            PCSX2/pcsx2         C++
# 9              freeCodeCamp/freeCodeCamp  TypeScript
# 10               public-apis/public-apis      Python
# 11                         csunny/DB-GPT      Python
# 12                      PrefectHQ/marvin      Python
# 13                     pengzhile/pandora      Python
# 14                 dissorial/doc-chatbot  TypeScript
# 15          Mikubill/sd-webui-controlnet      Python
# 16             brexhq/prompt-engineering         NaN
# 17                    XTLS/Trojan-killer          Go
# 18                      StanGirard/quivr      Python
# 19       openai/chatgpt-retrieval-plugin      Python
# 20             openai/plugins-quickstart      Python
# 21                     Bing-su/adetailer      Python
# 22                  sindresorhus/awesome         NaN
# 23                           e2b-dev/e2b      Python
# 24                windmill-labs/windmill  JavaScript
#
#                                       readme_contents
# 0   # privateGPT\nAsk questions to your documents ...
# 1   # FlipperAmiibo\nA collection of FlipperZero N...
# 2   <!--\nSPDX-FileCopyrightText: 2018 yuzu Emulat...
# 3   # Stable Diffusion web UI\r\nA browser interfa...
# 4   <h1 align="center">\n  <br>\n  <img height="30...
# 5   <div align="center">\n<img src="./docs/images/...
# 6   # WebWhiz\n\nTrain ChatGPT on Your Website Dat...
# 7   ## Playground (and dump) of stuff I made, modi...
# 8   # PCSX2\n\n![Windows Build Status](https://img...
# 9   [![freeCodeCamp Social Banner](https://s3.amaz...
# 10  <div align="center">\n    <h1>Public APIs</h1>...
# 11  # DB-GPT ![GitHub Repo stars](https://img.shie...
# 12  # Marvin 🤖🏖️\n\n![](docs/img/heroes/ai_model_w...
# 13  # Pandora\n\n潘多拉 (Pandora)，一个让你呼吸顺畅的 ChatGPT。\...
# 14  # doc-chatbot: GPT-4 x Pinecone x LangChain x ...
# 15  # ControlNet for Stable Diffusion WebUI\n\nThe...
# 16  # [Brex's](https://brex.com) Prompt Engineerin...
# 17  # Trojan-Killer\n\n这个 POC 是为了 **狠 狠 打 脸** 某些认为...
# 18  # Quivr\n\n<p align="center">\n<img src="./log...
# 19  # ChatGPT Retrieval Plugin\n\n> **Join the [Ch...
# 20  # ChatGPT plugins quickstart\n\nGet a todo lis...
# 21  # !After Detailer\n\n!After Detailer is a exte...
# 22  <div align="center">\n\t<a href="https://vshym...
# 23  <h1 align="center">\n  <img width="200" src="d...
# 24  <p align="center">\n  <a href="https://app.win...

# %%
df = prepare.transform_data(df)

# %%
df
# Out:
#                                     repo    language
# 0                   imartinez/privateGPT      Python  \
# 1                Gioman101/FlipperAmiibo      Python
# 2                          yuzu-emu/yuzu         C++
# 3   AUTOMATIC1111/stable-diffusion-webui      Python
# 4                      go-skynet/LocalAI          Go
# 5               Yidadaa/ChatGPT-Next-Web  TypeScript
# 6                     webwhiz-ai/webwhiz  TypeScript
# 7                     UberGuidoZ/Flipper           C
# 8                            PCSX2/pcsx2         C++
# 9              freeCodeCamp/freeCodeCamp  TypeScript
# 10               public-apis/public-apis      Python
# 11                         csunny/DB-GPT      Python
# 12                      PrefectHQ/marvin      Python
# 13                     pengzhile/pandora      Python
# 14                 dissorial/doc-chatbot  TypeScript
# 15          Mikubill/sd-webui-controlnet      Python
# 16             brexhq/prompt-engineering         NaN
# 17                    XTLS/Trojan-killer          Go
# 18                      StanGirard/quivr      Python
# 19       openai/chatgpt-retrieval-plugin      Python
# 20             openai/plugins-quickstart      Python
# 21                     Bing-su/adetailer      Python
# 22                  sindresorhus/awesome         NaN
# 23                           e2b-dev/e2b      Python
# 24                windmill-labs/windmill  JavaScript
#
#                                              original
# 0   # privateGPT\nAsk questions to your documents ...  \
# 1   # FlipperAmiibo\nA collection of FlipperZero N...
# 2   <!--\nSPDX-FileCopyrightText: 2018 yuzu Emulat...
# 3   # Stable Diffusion web UI\r\nA browser interfa...
# 4   <h1 align="center">\n  <br>\n  <img height="30...
# 5   <div align="center">\n<img src="./docs/images/...
# 6   # WebWhiz\n\nTrain ChatGPT on Your Website Dat...
# 7   ## Playground (and dump) of stuff I made, modi...
# 8   # PCSX2\n\n![Windows Build Status](https://img...
# 9   [![freeCodeCamp Social Banner](https://s3.amaz...
# 10  <div align="center">\n    <h1>Public APIs</h1>...
# 11  # DB-GPT ![GitHub Repo stars](https://img.shie...
# 12  # Marvin 🤖🏖️\n\n![](docs/img/heroes/ai_model_w...
# 13  # Pandora\n\n潘多拉 (Pandora)，一个让你呼吸顺畅的 ChatGPT。\...
# 14  # doc-chatbot: GPT-4 x Pinecone x LangChain x ...
# 15  # ControlNet for Stable Diffusion WebUI\n\nThe...
# 16  # [Brex's](https://brex.com) Prompt Engineerin...
# 17  # Trojan-Killer\n\n这个 POC 是为了 **狠 狠 打 脸** 某些认为...
# 18  # Quivr\n\n<p align="center">\n<img src="./log...
# 19  # ChatGPT Retrieval Plugin\n\n> **Join the [Ch...
# 20  # ChatGPT plugins quickstart\n\nGet a todo lis...
# 21  # !After Detailer\n\n!After Detailer is a exte...
# 22  <div align="center">\n\t<a href="https://vshym...
# 23  <h1 align="center">\n  <img width="200" src="d...
# 24  <p align="center">\n  <a href="https://app.win...
#
#                                                 clean
# 0   privategpt ask questions documents without int...  \
# 1   flipperamiibo collection flipperzero nfc files...
# 2   spdxfilecopyrighttext 2018 yuzu emulator proje...
# 3   stable diffusion web ui browser interface base...
# 4   h1 aligncenter br img height300 srchttpsuserim...
# 5   div aligncenter img srcdocsimagesiconsvg altic...
# 6   webwhiz train chatgpt website data build ai ch...
# 7   playground dump stuff made modified researched...
# 8   pcsx2 windows build statushttpsimgshieldsiogit...
# 9   freecodecamp social bannerhttpss3amazonawscomf...
# 10  div aligncenter h1public apish1 ia collective ...
# 11  dbgpt github repo starshttpsimgshieldsiogithub...
# 12  marvin docsimgheroesaimodelwindycityheropng me...
# 13  pandora pandora chatgpt chatgpt cloudflare pro...
# 14  docchatbot gpt4 x pinecone x langchain x mongo...
# 15  controlnet stable diffusion webui webui extens...
# 16  brexshttpsbrexcom prompt engineering guide gui...
# 17  trojankiller poc tls tls 12700112345 tls troja...
# 18  quivr p aligncenter img srclogopng altquivrlog...
# 19  chatgpt retrieval plugin join chatgpt plugins ...
# 20  chatgpt plugins quickstart get todo list chatg...
# 21  detailer detailer extension stable diffusion w...
# 22  div aligncenter &#9; hrefhttpsvshymanskyygithu...
# 23  h1 aligncenter img width200 srcdocsassetslogon...
# 24  p aligncenter hrefhttpsappwindmilldevimg srcim...
#
#                                               stemmed
# 0   privategpt ask question document without inter...  \
# 1   flipperamiibo collect flipperzero nfc file emu...
# 2   spdxfilecopyrighttext 2018 yuzu emul project s...
# 3   stabl diffus web ui browser interfac base grad...
# 4   h1 aligncent br img height300 srchttpsuserimag...
# 5   div aligncent img srcdocsimagesiconsvg alticon...
# 6   webwhiz train chatgpt websit data build ai cha...
# 7   playground dump stuff made modifi research fou...
# 8   pcsx2 window build statushttpsimgshieldsiogith...
# 9   freecodecamp social bannerhttpss3amazonawscomf...
# 10  div aligncent h1public apish1 ia collect list ...
# 11  dbgpt github repo starshttpsimgshieldsiogithub...
# 12  marvin docsimgheroesaimodelwindycityheropng me...
# 13  pandora pandora chatgpt chatgpt cloudflar proj...
# 14  docchatbot gpt4 x pinecon x langchain x mongod...
# 15  controlnet stabl diffus webui webui extens con...
# 16  brexshttpsbrexcom prompt engin guid guid creat...
# 17  trojankil poc tl tl 12700112345 tl trojan 1 ht...
# 18  quivr p aligncent img srclogopng altquivrlogo ...
# 19  chatgpt retriev plugin join chatgpt plugin wai...
# 20  chatgpt plugin quickstart get todo list chatgp...
# 21  detail detail extens stabl diffus webui simila...
# 22  div aligncent &#9; hrefhttpsvshymanskyygithubi...
# 23  h1 aligncent img width200 srcdocsassetslogonam...
# 24  p aligncent hrefhttpsappwindmilldevimg srcimgs...
#
#                                             lematized
# 0   privategpt ask question document without inter...
# 1   flipperamiibo collection flipperzero nfc file ...
# 2   spdxfilecopyrighttext 2018 yuzu emulator proje...
# 3   stable diffusion web ui browser interface base...
# 4   h1 aligncenter br img height300 srchttpsuserim...
# 5   div aligncenter img srcdocsimagesiconsvg altic...
# 6   webwhiz train chatgpt website data build ai ch...
# 7   playground dump stuff make modify research fin...
# 8   pcsx2 windows build statushttpsimgshieldsiogit...
# 9   freecodecamp social bannerhttpss3amazonawscomf...
# 10  div aligncenter h1public apish1 ia collective ...
# 11  dbgpt github repo starshttpsimgshieldsiogithub...
# 12  marvin docsimgheroesaimodelwindycityheropng me...
# 13  pandora pandora chatgpt chatgpt cloudflare pro...
# 14  docchatbot gpt4 x pinecone x langchain x mongo...
# 15  controlnet stable diffusion webui webui extens...
# 16  brexshttpsbrexcom prompt engineer guide guide ...
# 17  trojankiller poc tls tls 12700112345 tls troja...
# 18  quivr p aligncenter img srclogopng altquivrlog...
# 19  chatgpt retrieval plugin join chatgpt plugins ...
# 20  chatgpt plugins quickstart get todo list chatg...
# 21  detailer detailer extension stable diffusion w...
# 22  div aligncenter &#9; hrefhttpsvshymanskyygithu...
# 23  h1 aligncenter img width200 srcdocsassetslogon...
# 24  p aligncenter hrefhttpsappwindmilldevimg srcim...
